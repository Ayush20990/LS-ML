# %%
pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.2.54-py3-none-any.whl (800 kB)
# ...
#   Using cached ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
from IPython import display
display.clear_output()
import ultralytics

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=50 plots=True
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='runs/detect/train2/results.png',width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008768 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/datasets/car/valid/labels.cache... 160 images, 11 backgrounds, 0 corrupt: 100% 170/170 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11/11 [00:08<00:00,  1.32it/s]
#                    all        170       1055      0.689      0.694      0.676      0.487
#                   boot         35         39      0.524      0.462       0.44       0.35
#                    car        142        145      0.855      0.972      0.889      0.789
#                   door         50         52      0.814      0.769      0.805      0.598
#           front_bumper         30         30      0.668      0.335      0.442      0.275
#            front_grill         49         51      0.548      0.706       0.59      0.451
# ...

# %% [markdown]
# # New Section

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/datasets/car/test/images
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008768 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/22 /content/drive/MyDrive/datasets/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 license_plate, 1 taillamp, 8.1ms
# image 2/22 /content/drive/MyDrive/datasets/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 2 cars, 1 license_plate, 7.7ms
# image 3/22 /content/drive/MyDrive/datasets/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 2 cars, 2 license_plates, 7.4ms
# image 4/22 /content/drive/MyDrive/datasets/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 1 car, 1 front_grill, 1 headlamp, 1 license_plate, 1 taillamp, 7.4ms
# ...

# %%
# !zip -r /contents/runs.zip /contents/runs
# Out:
# 	zip warning: name not matched: /contents/runs
#
# zip error: Nothing to do! (try: zip -r /contents/runs.zip . -i /contents/runs)

# %%
# !zip -r /runs.zip /runs
# Out:
# 	zip warning: name not matched: /runs
#
# zip error: Nothing to do! (try: zip -r /runs.zip . -i /runs)

# %%
# !zip /content/runs/detect.zip /content/runs/detect/
# Out:
#   adding: content/runs/detect/ (stored 0%)
